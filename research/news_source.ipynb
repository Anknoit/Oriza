# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
# url = "https://www.spglobal.com/commodity-insights/en/news-research/latest-news#q=&rows=20&pagenum=1&sort=es_unified_dt%20desc"
url = "https://www.livemint.com/market/commodities"
response = requests.get(url)
html_content = response.text
html_content
soup = BeautifulSoup(html_content, "html.parser")
news = soup.find_all('h2', class_='headline')
# print(news)
for i in news:
    # print(i.get_text())
    news_text, news_link = i.get_text().strip(), f"{url}{i.a['href']}"
    # print(news_text, news_link)
    news_list = {
        "news" : news_text,
        "link" : news_link,
        "source" : "mint"
    }
    print(news_list)
# Out:
# {'news': 'Gold has sparkled for 4 Dhanteras — Will its good luck hit a 5-year streak?', 'link': 'https://www.livemint.com/market/commodities/market/commodities/gold-prices-have-sparkled-for-4-straight-dhanteras-will-gold-s-good-luck-hit-a-5-year-streak-11760682723453.html', 'source': 'mint'}
# {'news': 'Gold, silver prices hit record highs on MCX; Key levels to watch', 'link': 'https://www.livemint.com/market/commodities/market/commodities/gold-price-today-rates-of-gold-silver-on-mcx-is-it-the-right-time-to-buy-gold-should-you-buy-silver-11760668416808.html', 'source': 'mint'}
# {'news': 'ASIA RICE-Thai prices extend slump to 18-year low as demand falters', 'link': 'https://www.livemint.com/market/commodities/market/commodities/asia-rice-thai-prices-extend-slump-to-18-year-low-as-demand-falters-11760664684388.html', 'source': 'mint'}
# ...
