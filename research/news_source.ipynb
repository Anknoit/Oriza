# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /home/ankit/anaconda3/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ankit/anaconda3/lib/python3.13/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ankit/anaconda3/lib/python3.13/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ankit/anaconda3/lib/python3.13/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ankit/anaconda3/lib/python3.13/site-packages (from requests) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
# url = "https://www.spglobal.com/commodity-insights/en/news-research/latest-news#q=&rows=20&pagenum=1&sort=es_unified_dt%20desc"
url = "https://www.livemint.com/market/commodities"
response = requests.get(url)
html_content = response.text
html_content
soup = BeautifulSoup(html_content, "html.parser")
news = soup.find_all('h2', class_='headline')
# print(news)
for i in news:
    # print(i.get_text())
    news_text, news_link = i.get_text().strip(), url
    # print(news_text, news_link)
    news_list = {
        "news" : news_text,
        "link" : news_link,
        "source" : "mint"
    }
    print(news_list)
# Out:
# {'news': 'Gold has sparkled for 4 Dhanteras — Will its good luck hit a 5-year streak?', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold, silver prices hit record highs on MCX; Key levels to watch', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'ASIA RICE-Thai prices extend slump to 18-year low as demand falters', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold price hits record high, on track to log biggest weekly gain since 2008', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Oil set for weekly loss as Trump-Putin summit looms', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold price today: Rates hit a new high of $4,289 on Comex', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'What could stop the gold rally in its tracks? Not much.', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Crude oil prices gain on reports India may scale back Russian crude imports', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold, silver prices scale record highs — Is this the peak?', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'How to still buy gold this Dhanteras and wedding season amid sky-high prices?', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold, silver hit new highs; what should investors do?', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Oil prices dip, stay\xa0near 5-month low on US-China trade tensions, looming supply surplus', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'MCX gold price hits record high above ₹1.27 lakh per 10 grams', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold rate today in India on Oct 15: Check rates in Mumbai, Delhi, Kokata today', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold surges past $4,100 per ounce driven by possible fed interest rate cut bets', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold climbs to new peak amid trade tension. Will it rally more?', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold prices today in your city: Check rates in Mumbai, Delhi on October 14', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'MCX gold, silver hit new record highs on safe-haven demand', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Gold rockets to record high $4,116, up 56% this year', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
# {'news': 'Sentiment steadies after Trump cools rhetoric on China, gold at record highs', 'link': 'https://www.livemint.com/market/commodities', 'source': 'mint'}
